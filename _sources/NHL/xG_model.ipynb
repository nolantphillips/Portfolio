# %% [markdown]
# # xG Model Notebook

# %%
from nhlpy import NHLClient
import csv
import pandas as pd
import matplotlib.pyplot as plt
import math
import numpy as np
from ydata_profiling import ProfileReport
import seaborn as sns

# %%
# %config InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# Read the data from the scraper into a Pandas data frame and clean the data.

# %%
df = pd.read_csv('nhl_shot_data.csv')
df.head()
# Out:
#    Unnamed: 0     game_id  team_id  home     last_play  rebound  rush  \
# 0           0  2022020023       52     1      giveaway        0     1
# 1           1  2022020023       52     1           hit        0     0
# 2           2  2022020023        3     0  shot-on-goal        0     0
# 3           3  2022020023       52     1           hit        0     0
# 4           4  2022020023       52     1           hit        0     0
#
#    home_skaters  away_skaters  x_coord  y_coord  shooter  assist1  assist2  \
# 0             5             5       77        6  8480289        0        0
# 1             5             5       30       30  8480145        0        0
# 2             5             5       35       30  8479333        0        0
# 3             5             5       41       14  8471218        0        0
# 4             5             5       46       17  8471218        0        0
#
#     goalie shot_type    shot_class
# 0  8470860     wrist  shot-on-goal
# 1  8470860      slap  shot-on-goal
# 2  8476945     wrist  shot-on-goal
# 3  8470860     wrist  shot-on-goal
# 4  8470860     wrist  shot-on-goal

# %%
df.drop('Unnamed: 0', axis = 1, inplace=True)
df.head()
# Out:
#       game_id  team_id  home     last_play  rebound  rush  home_skaters  \
# 0  2022020023       52     1      giveaway        0     1             5
# 1  2022020023       52     1           hit        0     0             5
# 2  2022020023        3     0  shot-on-goal        0     0             5
# 3  2022020023       52     1           hit        0     0             5
# 4  2022020023       52     1           hit        0     0             5
#
#    away_skaters  x_coord  y_coord  shooter  assist1  assist2   goalie  \
# 0             5       77        6  8480289        0        0  8470860
# 1             5       30       30  8480145        0        0  8470860
# 2             5       35       30  8479333        0        0  8476945
# 3             5       41       14  8471218        0        0  8470860
# 4             5       46       17  8471218        0        0  8470860
#
#   shot_type    shot_class
# 0     wrist  shot-on-goal
# 1      slap  shot-on-goal
# 2     wrist  shot-on-goal
# 3     wrist  shot-on-goal
# 4     wrist  shot-on-goal

# %%
shots = df.drop(['game_id', 'team_id', 'assist1', 'assist2'], axis=1)
shots.head()
# Out:
#    home     last_play  rebound  rush  home_skaters  away_skaters  x_coord  \
# 0     1      giveaway        0     1             5             5       77
# 1     1           hit        0     0             5             5       30
# 2     0  shot-on-goal        0     0             5             5       35
# 3     1           hit        0     0             5             5       41
# 4     1           hit        0     0             5             5       46
#
#    y_coord  shooter   goalie shot_type    shot_class
# 0        6  8480289  8470860     wrist  shot-on-goal
# 1       30  8480145  8470860      slap  shot-on-goal
# 2       30  8479333  8476945     wrist  shot-on-goal
# 3       14  8471218  8470860     wrist  shot-on-goal
# 4       17  8471218  8470860     wrist  shot-on-goal

# %% [markdown]
# The code below adds every team abbreviation into a list. These abbreviatons were then used to gather the rosters for each NHL team and add their players into a dictionary mapping a player's name to their player ID.

# %%
client = NHLClient()
teams = client.teams.teams_info()
team_abbrs = []
for item in teams:
    abbr = item['abbr']
    team_abbrs.append(abbr)

# %%
player_dict = {}

for season in [20222023, 20232024, 20242025]:
    for abbreviation in team_abbrs:
    
        if abbreviation == 'UTA' and season != 20242025:
            abbreviation = 'ARI'

        roster = client.teams.roster(team_abbr=abbreviation, season=season)
        for player in roster['forwards']:
            if player['id'] in player_dict:
                continue
            player_dict[player['id']] = player['firstName']['default'] + ' ' + player['lastName']['default']

        for player in roster['defensemen']:
            if player['id'] in player_dict:
                continue
            player_dict[player['id']] = player['firstName']['default'] + ' ' + player['lastName']['default']

        for player in roster['goalies']:
            if player['id'] in player_dict:
                continue
            player_dict[player['id']] = player['firstName']['default'] + ' ' + player['lastName']['default']

# %%
shots['shooter'] = shots['shooter'].replace(player_dict)
shots['goalie'] = shots['goalie'].replace(player_dict)

# %% [markdown]
# Numerical data that would not have made much sense to remain as numerical data types are mapped to categorical types. Rebounds and rush chances were determined by the time difference between events.

# %%
home_mapping = {}
home_mapping[0] ='Away'
home_mapping[1] = 'Home'

rebound_mapping = {}
rebound_mapping[0] = 'No rebound'
rebound_mapping[1] ='Rebound'

rush_mapping = {}
rush_mapping[0] = 'No rush'
rush_mapping[1] ='Rush'

# %%
shots['home'] = shots['home'].replace(home_mapping)
shots['rebound'] = shots['rebound'].replace(rebound_mapping)
shots['rush'] = shots['rush'].replace(rush_mapping)

# %%
shots['shooter'] = shots['shooter'].apply(lambda x: 'unknown' if isinstance(x, int) else x)
shots['goalie'] = shots['goalie'].apply(lambda x: 'unknown' if isinstance(x, int) else x)

# %%
shots = shots[shots['shooter'] != 'unknown']
shots = shots[shots['goalie'] != 'unknown']

# %%
shots.head(30)
# Out:
#     home     last_play     rebound     rush  home_skaters  away_skaters  \
# 0   Home      giveaway  No rebound     Rush             5             5
# 1   Home           hit  No rebound  No rush             5             5
# 2   Away  shot-on-goal  No rebound  No rush             5             5
# 3   Home           hit  No rebound  No rush             5             5
# 4   Home           hit  No rebound  No rush             5             5
# 5   Home           hit  No rebound  No rush             5             5
# 6   Home   missed-shot  No rebound  No rush             5             5
# 7   Away       faceoff  No rebound  No rush             4             5
# 8   Away  shot-on-goal     Rebound  No rush             4             5
# 9   Away  shot-on-goal  No rebound  No rush             4             5
# 10  Home  blocked-shot  No rebound  No rush             4             4
# 11  Home  shot-on-goal  No rebound  No rush             4             4
# 12  Home  blocked-shot  No rebound  No rush             4             4
# 13  Away  blocked-shot  No rebound  No rush             5             5
# 14  Home      giveaway  No rebound  No rush             5             5
# 15  Away           hit  No rebound  No rush             5             5
# 16  Away  shot-on-goal     Rebound  No rush             5             5
# 17  Home      giveaway  No rebound     Rush             5             5
# 18  Away   missed-shot  No rebound  No rush             5             5
# 19  Away  shot-on-goal  No rebound  No rush             5             5
# 20  Home      giveaway  No rebound     Rush             5             5
# 21  Home           hit  No rebound  No rush             5             5
# 22  Home       faceoff  No rebound  No rush             5             5
# 23  Home       faceoff  No rebound  No rush             5             5
# 24  Home  blocked-shot  No rebound  No rush             5             5
# 25  Away      giveaway  No rebound  No rush             5             5
# 26  Away      giveaway  No rebound     Rush             5             5
# 27  Home           hit  No rebound  No rush             5             5
# 28  Home   missed-shot  No rebound  No rush             5             5
# 29  Away       faceoff  No rebound  No rush             5             5
#
#     x_coord  y_coord           shooter             goalie  shot_type  \
# 0        77        6     Morgan Barron     Jaroslav Halak      wrist
# 1        30       30        Neal Pionk     Jaroslav Halak       slap
# 2        35       30       Libor Hajek  Connor Hellebuyck      wrist
# 3        41       14     Blake Wheeler     Jaroslav Halak      wrist
# 4        46       17     Blake Wheeler     Jaroslav Halak      wrist
# 5        81      -27    Nikolaj Ehlers     Jaroslav Halak      wrist
# 6        34       30        Neal Pionk     Jaroslav Halak      wrist
# 7        69        2  Vincent Trocheck  Connor Hellebuyck  deflected
# 8        78        5     Chris Kreider  Connor Hellebuyck      wrist
# 9        45       -6    Artemi Panarin  Connor Hellebuyck      wrist
# 10       80       -9    Mark Scheifele     Jaroslav Halak   backhand
# 11       59       15       Kyle Connor     Jaroslav Halak       snap
# 12       52      -20    Mark Scheifele     Jaroslav Halak      wrist
# 13       78        2    Artemi Panarin  Connor Hellebuyck   backhand
# 14       66       -5    Mark Scheifele     Jaroslav Halak      wrist
# 15       87       -6   Barclay Goodrow  Connor Hellebuyck       snap
# 16       87       -6   Barclay Goodrow  Connor Hellebuyck       poke
# 17       53        0       Kyle Connor     Jaroslav Halak       snap
# 18       37      -11      Jacob Trouba  Connor Hellebuyck      wrist
# 19       35       32    K'Andre Miller  Connor Hellebuyck      wrist
# 20       44      -29     Logan Stanley     Jaroslav Halak      wrist
# 21       81        8      Dylan DeMelo     Jaroslav Halak       snap
# 22       71        4        Sam Gagner     Jaroslav Halak       poke
# 23       51      -22   Saku Maenalanen     Jaroslav Halak       snap
# 24       70       20    Nikolaj Ehlers     Jaroslav Halak       snap
# 25       80        0    Mika Zibanejad  Connor Hellebuyck     tip-in
# 26       38      -14       Kaapo Kakko  Connor Hellebuyck       snap
# 27       69      -34     Cole Perfetti     Jaroslav Halak      wrist
# 28       58       26     Blake Wheeler     Jaroslav Halak      wrist
# 29       35       24    K'Andre Miller  Connor Hellebuyck      wrist
#
#       shot_class
# 0   shot-on-goal
# 1   shot-on-goal
# 2   shot-on-goal
# 3   shot-on-goal
# 4   shot-on-goal
# 5    missed-shot
# 6   shot-on-goal
# 7   shot-on-goal
# 8   shot-on-goal
# 9   shot-on-goal
# 10  shot-on-goal
# 11  shot-on-goal
# 12  shot-on-goal
# 13  shot-on-goal
# 14          goal
# 15  shot-on-goal
# 16  shot-on-goal
# 17   missed-shot
# 18  shot-on-goal
# 19   missed-shot
# 20   missed-shot
# 21  shot-on-goal
# 22  shot-on-goal
# 23  shot-on-goal
# 24   missed-shot
# 25  shot-on-goal
# 26  shot-on-goal
# 27   missed-shot
# 28  shot-on-goal
# 29  shot-on-goal

# %%
# Fix scraper to convert the home and away ID to find the team abbreviation via a dictionary

# %%
shots.info()
shots.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 579375 entries, 0 to 586564
# Data columns (total 12 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   home          579375 non-null  object
#  1   last_play     579375 non-null  object
#  2   rebound       579375 non-null  object
#  3   rush          579375 non-null  object
#  4   home_skaters  579375 non-null  int64
#  5   away_skaters  579375 non-null  int64
#  6   x_coord       579375 non-null  int64
#  7   y_coord       579375 non-null  int64
#  8   shooter       579375 non-null  object
#  9   goalie        579375 non-null  object
#  10  shot_type     579375 non-null  object
#  11  shot_class    579375 non-null  object
# dtypes: int64(4), object(8)
# memory usage: 57.5+ MB
#         home_skaters   away_skaters        x_coord        y_coord
# count  579375.000000  579375.000000  579375.000000  579375.000000
# mean        4.869710       4.860098      62.010991      -0.178903
# std         0.494412       0.504575      19.031434      19.723686
# min         0.000000       0.000000       0.000000     -42.000000
# 25%         5.000000       5.000000      49.000000     -15.000000
# 50%         5.000000       5.000000      65.000000       0.000000
# 75%         5.000000       5.000000      78.000000      14.000000
# max         6.000000       6.000000     100.000000      42.000000

# %%
df['shot_class'].value_counts()
shots['shooter'].value_counts()
# Out:
# shot_class
# shot-on-goal    369817
# missed-shot     176428
# goal             40320
# Name: count, dtype: int64
# shooter
# David Pastrnak      2756
# Nathan MacKinnon    2628
# Auston Matthews     2480
# Brady Tkachuk       2320
# Matthew Tkachuk     2278
#                     ...
# Arvid Soderblom        2
# Anton Levtchi          2
# Anthony Stolarz        2
# Jonathan Quick         2
# Cole Bardreau          2
# Name: count, Length: 1060, dtype: int64

# %% [markdown]
# The code below creates a new feature called shot angle.

# %%
# Every shot is plotted on one half of the ice, the red line is at x = 0, the blue line is at x = 25, goal line at x = 89, all measurements are in feet.
# Use this information to create an angle to the net feature
def angle(x_coord, y_coord):
    x_centered = 89 - x_coord
    return round(np.degrees(np.arctan(y_coord/x_centered)), 2)

shots['angles'] = angle(shots['x_coord'], shots['y_coord'])
shots['goal'] = np.where(shots['shot_class'] == 'goal', 1, 0)
shots.drop('shot_class', axis=1, inplace=True)
shots.head()
shots['rebound'].value_counts()
shots['rush'].value_counts()
shots['home_skaters'].value_counts()
shots['away_skaters'].value_counts()
shots['goal'].value_counts()
# Out:
#    home     last_play     rebound     rush  home_skaters  away_skaters  \
# 0  Home      giveaway  No rebound     Rush             5             5
# 1  Home           hit  No rebound  No rush             5             5
# 2  Away  shot-on-goal  No rebound  No rush             5             5
# 3  Home           hit  No rebound  No rush             5             5
# 4  Home           hit  No rebound  No rush             5             5
#
#    x_coord  y_coord        shooter             goalie shot_type  angles  goal
# 0       77        6  Morgan Barron     Jaroslav Halak     wrist   26.57     0
# 1       30       30     Neal Pionk     Jaroslav Halak      slap   26.95     0
# 2       35       30    Libor Hajek  Connor Hellebuyck     wrist   29.05     0
# 3       41       14  Blake Wheeler     Jaroslav Halak     wrist   16.26     0
# 4       46       17  Blake Wheeler     Jaroslav Halak     wrist   21.57     0
# rebound
# No rebound    525248
# Rebound        54127
# Name: count, dtype: int64
# rush
# No rush    559691
# Rush        19684
# Name: count, dtype: int64
# home_skaters
# 5    509036
# 4     53356
# 3      7494
# 6      6454
# 1      1578
# 0      1457
# Name: count, dtype: int64
# away_skaters
# 5    504382
# 4     57585
# 3      8042
# 6      6331
# 0      1578
# 1      1457
# Name: count, dtype: int64
# goal
# 0    539538
# 1     39837
# Name: count, dtype: int64

# %%
shots = shots[shots['home_skaters'] >= 3]
shots = shots[shots['away_skaters'] >= 3]

# %%
shots.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 576340 entries, 0 to 586564
# Data columns (total 13 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   home          576340 non-null  object
#  1   last_play     576340 non-null  object
#  2   rebound       576340 non-null  object
#  3   rush          576340 non-null  object
#  4   home_skaters  576340 non-null  int64
#  5   away_skaters  576340 non-null  int64
#  6   x_coord       576340 non-null  int64
#  7   y_coord       576340 non-null  int64
#  8   shooter       576340 non-null  object
#  9   goalie        576340 non-null  object
#  10  shot_type     576340 non-null  object
#  11  angles        576332 non-null  float64
#  12  goal          576340 non-null  int32
# dtypes: float64(1), int32(1), int64(4), object(7)
# memory usage: 59.4+ MB

# %%
shots.dropna(inplace=True)

# %%
numerical_cols = shots[['home_skaters','away_skaters','x_coord','y_coord', 'angles', 'goal']]
numerical_cols.head()
numerical_cols.corr().style.background_gradient(cmap='coolwarm')
# Out:
#    home_skaters  away_skaters  x_coord  y_coord  angles  goal
# 0             5             5       77        6   26.57     0
# 1             5             5       30       30   26.95     0
# 2             5             5       35       30   29.05     0
# 3             5             5       41       14   16.26     0
# 4             5             5       46       17   21.57     0
# <style type="text/css">
# #T_d3580_row0_col0, #T_d3580_row1_col1, #T_d3580_row2_col2, #T_d3580_row3_col3, #T_d3580_row4_col4, #T_d3580_row5_col5 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_d3580_row0_col1 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_d3580_row0_col2, #T_d3580_row2_col4 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_d3580_row0_col3, #T_d3580_row0_col4, #T_d3580_row0_col5, #T_d3580_row1_col2, #T_d3580_row1_col3, #T_d3580_row1_col4, #T_d3580_row1_col5, #T_d3580_row2_col0, #T_d3580_row2_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_d3580_row1_col0 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_d3580_row2_col3, #T_d3580_row5_col0, #T_d3580_row5_col3, #T_d3580_row5_col4 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_d3580_row2_col5 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_d3580_row3_col0, #T_d3580_row4_col0, #T_d3580_row4_col5 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_d3580_row3_col1, #T_d3580_row4_col1 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_d3580_row3_col2 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_d3580_row3_col4, #T_d3580_row4_col3 {
#   background-color: #ee8669;
#   color: #f1f1f1;
# }
# #T_d3580_row3_col5 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_d3580_row4_col2 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_d3580_row5_col1 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_d3580_row5_col2 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_d3580">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d3580_level0_col0" class="col_heading level0 col0" >home_skaters</th>
#       <th id="T_d3580_level0_col1" class="col_heading level0 col1" >away_skaters</th>
#       <th id="T_d3580_level0_col2" class="col_heading level0 col2" >x_coord</th>
#       <th id="T_d3580_level0_col3" class="col_heading level0 col3" >y_coord</th>
#       <th id="T_d3580_level0_col4" class="col_heading level0 col4" >angles</th>
#       <th id="T_d3580_level0_col5" class="col_heading level0 col5" >goal</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d3580_level0_row0" class="row_heading level0 row0" >home_skaters</th>
#       <td id="T_d3580_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_d3580_row0_col1" class="data row0 col1" >0.276631</td>
#       <td id="T_d3580_row0_col2" class="data row0 col2" >-0.054122</td>
#       <td id="T_d3580_row0_col3" class="data row0 col3" >-0.002870</td>
#       <td id="T_d3580_row0_col4" class="data row0 col4" >-0.002875</td>
#       <td id="T_d3580_row0_col5" class="data row0 col5" >-0.043745</td>
#     </tr>
#     <tr>
#       <th id="T_d3580_level0_row1" class="row_heading level0 row1" >away_skaters</th>
#       <td id="T_d3580_row1_col0" class="data row1 col0" >0.276631</td>
#       <td id="T_d3580_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_d3580_row1_col2" class="data row1 col2" >-0.060721</td>
#       <td id="T_d3580_row1_col3" class="data row1 col3" >-0.006117</td>
#       <td id="T_d3580_row1_col4" class="data row1 col4" >-0.006737</td>
#       <td id="T_d3580_row1_col5" class="data row1 col5" >-0.046501</td>
#     </tr>
#     <tr>
#       <th id="T_d3580_level0_row2" class="row_heading level0 row2" >x_coord</th>
#       <td id="T_d3580_row2_col0" class="data row2 col0" >-0.054122</td>
#       <td id="T_d3580_row2_col1" class="data row2 col1" >-0.060721</td>
#       <td id="T_d3580_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_d3580_row2_col3" class="data row2 col3" >0.004365</td>
#       <td id="T_d3580_row2_col4" class="data row2 col4" >-0.001764</td>
#       <td id="T_d3580_row2_col5" class="data row2 col5" >0.136724</td>
#     </tr>
#     <tr>
#       <th id="T_d3580_level0_row3" class="row_heading level0 row3" >y_coord</th>
#       <td id="T_d3580_row3_col0" class="data row3 col0" >-0.002870</td>
#       <td id="T_d3580_row3_col1" class="data row3 col1" >-0.006117</td>
#       <td id="T_d3580_row3_col2" class="data row3 col2" >0.004365</td>
#       <td id="T_d3580_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_d3580_row3_col4" class="data row3 col4" >0.794822</td>
#       <td id="T_d3580_row3_col5" class="data row3 col5" >0.002464</td>
#     </tr>
#     <tr>
#       <th id="T_d3580_level0_row4" class="row_heading level0 row4" >angles</th>
#       <td id="T_d3580_row4_col0" class="data row4 col0" >-0.002875</td>
#       <td id="T_d3580_row4_col1" class="data row4 col1" >-0.006737</td>
#       <td id="T_d3580_row4_col2" class="data row4 col2" >-0.001764</td>
#       <td id="T_d3580_row4_col3" class="data row4 col3" >0.794822</td>
#       <td id="T_d3580_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_d3580_row4_col5" class="data row4 col5" >0.003236</td>
#     </tr>
#     <tr>
#       <th id="T_d3580_level0_row5" class="row_heading level0 row5" >goal</th>
#       <td id="T_d3580_row5_col0" class="data row5 col0" >-0.043745</td>
#       <td id="T_d3580_row5_col1" class="data row5 col1" >-0.046501</td>
#       <td id="T_d3580_row5_col2" class="data row5 col2" >0.136724</td>
#       <td id="T_d3580_row5_col3" class="data row5 col3" >0.002464</td>
#       <td id="T_d3580_row5_col4" class="data row5 col4" >0.003236</td>
#       <td id="T_d3580_row5_col5" class="data row5 col5" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# The data is split into training and testing data.

# %%
# Perform 80/20 training/test split and stratify based on loan approval
from sklearn.model_selection import train_test_split
strat_train_set, strat_test_set = train_test_split(shots, test_size=0.20, stratify=shots['goal'], random_state=42)
strat_train_set["goal"].value_counts() / len(strat_train_set)
strat_test_set["goal"].value_counts() / len(strat_test_set)
shots_train = strat_train_set.drop(['goal'], axis=1)
shots_test = strat_test_set.drop(['goal'], axis=1)
property = strat_train_set["goal"].copy()
property_test = strat_test_set['goal'].copy()
# Out:
# goal
# 0    0.932628
# 1    0.067372
# Name: count, dtype: float64
# goal
# 0    0.932626
# 1    0.067374
# Name: count, dtype: float64

# %% [markdown]
# A preprocessing pipeline is created to convert the data into a usable data type for the model. It encodes categorical data to a numerical data type and scales the numerical data type.

# %%
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler, FunctionTransformer, StandardScaler
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.compose import ColumnTransformer, make_column_selector, make_column_transformer

cat_pipeline = make_pipeline(OneHotEncoder(handle_unknown="ignore"))
num_pipeline = make_pipeline(StandardScaler(), MinMaxScaler((-1,1)))

preprocessing = ColumnTransformer([
        ("cat", cat_pipeline, make_column_selector(dtype_include=object)),
    ],
    remainder=num_pipeline)

# %%
shots_prepped = preprocessing.fit_transform(shots_train)

# %%
from sklearn.linear_model import LogisticRegression

log_reg = make_pipeline(preprocessing, LogisticRegression())
log_reg.fit(shots_train, property)
goal_predictions = log_reg.predict(shots_train)
goal_predictions[:5].round(-2) 
property.iloc[:5].values
# Out:
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder=Pipeline(steps=[('standardscaler',
#                                                               StandardScaler()),
#                                                              ('minmaxscaler',
#                                                               MinMaxScaler(feature_range=(-1,
#                                                                                           1)))]),
#                                    transformers=[('cat',
#                                                   Pipeline(steps=[('onehotencoder',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x00000241814AC230>)])),
#                 ('logisticregression', LogisticRegression())])
# array([0, 0, 0, 0, 0])
# array([0, 0, 1, 0, 0])

# %%
probabilities_log = log_reg.predict_proba(shots_test)
pred_test = log_reg.predict(shots_test)

# %%
from sklearn.metrics import roc_auc_score, confusion_matrix, classification_report

auc_test = roc_auc_score(property_test, probabilities_log[:,1])
auc_train = roc_auc_score(property, log_reg.predict_proba(shots_train)[:,1])

confusion_matrix(property_test, pred_test)
print(classification_report(property_test, pred_test))
# Out:
# array([[107497,      4],
#        [  7752,     14]], dtype=int64)
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.97    107501
#            1       0.78      0.00      0.00      7766
#
#     accuracy                           0.93    115267
#    macro avg       0.86      0.50      0.48    115267
# weighted avg       0.92      0.93      0.90    115267

# %% [markdown]
# The logistic regression AUC  was low. It was decided that an XGBoost model should be built and compared to the logistic model.

# %%
auc_test
auc_train
# Out:
# 0.6963099239465178
# 0.7073842972565992

# %%
# Low AUC, try XG Boost classifier to see if that works better

# %%
from xgboost import XGBClassifier

xgb = make_pipeline(preprocessing, XGBClassifier())
xgb.fit(shots_train, property)
goal_predictions_xgb = xgb.predict(shots_train)
goal_predictions_xgb[:5].round(-2) 
property.iloc[:5].values
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder=Pipeline(steps=[('standardscaler',
#                                                               StandardScaler()),
#                                                              ('minmaxscaler',
#                                                               MinMaxScaler(feature_range=(-1,
#                                                                                           1)))]),
#                                    transformers=[('cat',
#                                                   Pipeline(steps=[('onehotencoder',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x00000241814AC230...
#                                feature_types=None, gamma=None, grow_policy=None,
#                                importance_type=None,
#                                interaction_constraints=None, learning_rate=None,
#                                max_bin=None, max_cat_threshold=None,
#                                max_cat_to_onehot=None, max_delta_step=None,
#                                max_depth=None, max_leaves=None,
#                                min_child_weight=None, missing=nan,
#                                monotone_constraints=None, multi_strategy=None,
#                                n_estimators=None, n_jobs=None,
#                                num_parallel_tree=None, random_state=None, ...))])
# array([0, 0, 0, 0, 0])
# array([0, 0, 1, 0, 0])

# %%
probabilities_xgb = xgb.predict_proba(shots_test)
pred_test_xgb = xgb.predict(shots_test)

# %%
auc_test = roc_auc_score(property_test, probabilities_xgb[:,1])
auc_train = roc_auc_score(property, xgb.predict_proba(shots_train)[:,1])

confusion_matrix(property_test, pred_test_xgb)
print(classification_report(property_test, pred_test_xgb))
# Out:
# array([[107490,     11],
#        [  7729,     37]], dtype=int64)
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.97    107501
#            1       0.77      0.00      0.01      7766
#
#     accuracy                           0.93    115267
#    macro avg       0.85      0.50      0.49    115267
# weighted avg       0.92      0.93      0.90    115267

# %% [markdown]
# The XGBoost model AUC was greatly improved from the logistic regression model. The XGBoost model should be fine tuned to increase AUC even more.

# %%
auc_test
auc_train
# Out:
# 0.7738028114768203
# 0.8011812064092082

# %%
import joblib

joblib.dump(xgb, 'xgb_base_v1.pkl')
# Out:
# ['xgb_base_v1.pkl']

# %%
from sklearn.model_selection import GridSearchCV
import cupy as cp

parameters = {
    'device' : ['cuda'],
    'n_estimators': [100, 250, 375, 500],
    'learning_rate': [0.01,0.05,0.1],
    'booster': ['gbtree', 'gblinear'],
    'gamma': [0, 0.5, 1],
    'reg_alpha': [0, 0.5, 1],
    'reg_lambda': [0.5, 1, 5],   
}

xgb_v2 = make_pipeline(preprocessing, GridSearchCV(XGBClassifier(n_jobs=-1), parameters, scoring='roc_auc'))
xgb_v2.fit(shots_train, property)
# Out:
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:16:44] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:16:47] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:16:49] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:16:52] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:16:54] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:16:57] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:16:59] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:17:02] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:17:04] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:17:07] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:17:09] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:17:12] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:17:14] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:17:17] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:17:19] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:17:22] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:17:23] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:17:25] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:17:27] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:17:29] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:17:30] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:17:32] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:17:34] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:17:36] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:17:37] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:17:39] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:17:41] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:17:43] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:17:44] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:17:46] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:17:48] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:17:50] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:17:51] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:17:53] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:17:55] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:17:57] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:17:58] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:18:00] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:18:02] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:18:04] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:18:05] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:18:07] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:18:09] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:18:11] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:18:12] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:18:14] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:18:20] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:18:26] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:18:32] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:18:38] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:18:43] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:18:49] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:18:55] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:19:01] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:19:07] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:19:12] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:19:18] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:19:24] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:19:30] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:19:36] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:19:41] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:19:46] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:19:50] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:19:54] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:19:58] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:20:02] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:20:06] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:20:10] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:20:14] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:20:18] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:20:22] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:20:26] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:20:30] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:20:34] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:20:38] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:20:43] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:20:47] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:20:51] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:20:55] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:20:59] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:21:03] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:21:07] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:21:11] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:21:15] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:21:19] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:21:23] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:21:27] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:21:31] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:21:35] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:21:39] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:21:43] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:21:52] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:22:01] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:22:09] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:22:18] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:22:27] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:22:35] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:22:44] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:22:52] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:23:01] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:23:10] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:23:18] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:23:27] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:23:35] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:23:44] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:23:53] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:23:59] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:24:05] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:24:11] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:24:17] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:24:23] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:24:29] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:24:35] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:24:41] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:24:47] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:24:53] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:24:59] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:25:05] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [10:25:11] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# ...
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [12:44:57] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [12:45:08] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [12:45:20] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [12:45:31] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [12:45:42] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [12:45:50] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [12:45:58] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [12:46:06] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [12:46:14] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [12:46:22] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [12:46:30] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [12:46:38] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [12:46:46] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [12:46:54] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [12:47:02] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [12:47:10] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [12:47:18] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [12:47:26] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [12:47:34] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [12:47:42] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [12:47:50] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [12:47:58] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [12:48:06] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [12:48:14] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [12:48:22] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [12:48:30] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [12:48:38] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [12:48:46] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [12:48:54] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [12:49:01] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [12:49:09] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [12:49:17] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [12:49:25] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\nolan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\xgboost\core.py:158: UserWarning: [12:49:33] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "gamma" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder=Pipeline(steps=[('standardscaler',
#                                                               StandardScaler()),
#                                                              ('minmaxscaler',
#                                                               MinMaxScaler(feature_range=(-1,
#                                                                                           1)))]),
#                                    transformers=[('cat',
#                                                   Pipeline(steps=[('onehotencoder',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x00000241814AC230...
#                                                       min_child_weight=None,
#                                                       missing=nan,
#                                                       monotone_constraints=None,
#                                                       multi_strategy=None,
#                                                       n_estimators=None,
#                                                       n_jobs=-1,
#                                                       num_parallel_tree=None,
#                                                       random_state=None, ...),
#                               param_grid={'booster': ['gbtree', 'gblinear'],
#                                           'device': ['cuda'],
#                                           'gamma': [0, 0.5, 1],
#                                           'learning_rate': [0.01, 0.05, 0.1],
#                                           'n_estimators': [100, 250, 375, 500],
#                                           'reg_alpha': [0, 0.5, 1],
#                                           'reg_lambda': [0.5, 1, 5]},
#                               scoring='roc_auc'))])

# %%
goal_predictions_xgb_v2 = xgb_v2.predict(shots_train)
goal_predictions_xgb_v2[:5].round(-2) 
property.iloc[:5].values
# Out:
# array([0, 0, 0, 0, 0])
# array([0, 0, 1, 0, 0])

# %%
probabilities_xgb_v2 = xgb_v2.predict_proba(shots_test)
pred_test_xgb_v2 = xgb_v2.predict(shots_test)

# %%
auc_test = roc_auc_score(property_test, probabilities_xgb_v2[:,1])
auc_train = roc_auc_score(property, xgb_v2.predict_proba(shots_train)[:,1])

confusion_matrix(property_test, pred_test_xgb_v2)
print(classification_report(property_test, pred_test_xgb_v2))
# Out:
# array([[107484,     17],
#        [  7714,     52]], dtype=int64)
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.97    107501
#            1       0.75      0.01      0.01      7766
#
#     accuracy                           0.93    115267
#    macro avg       0.84      0.50      0.49    115267
# weighted avg       0.92      0.93      0.90    115267

# %% [markdown]
# The AUC was slightly increased compared to the base XGBoost model.

# %%
auc_test
auc_train
# Out:
# 0.7836202012415684
# 0.8204006516605874

# %%
joblib.dump(xgb_v2, 'xgb_v2.pkl')
# Out:
# ['xgb_v2.pkl']
